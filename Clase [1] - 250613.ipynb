# %% [markdown]
# <p align="right">
#   <img
#     src="https://drive.google.com/uc?export=view&id=1CzGTq7D3I3CwRf5cfzAgK7H8xK5KNYDk"
#     alt="pypl"
#     width="300%"
#     height="20%">
# </p>

# %% [markdown]
# # Librerías

# %% [markdown]
# Hasta ahora, hemos usado solamente funciones y estructuras disponibles en la instalación base de Python, pero una de las fortalezas del lenguaje es su comunidad y todo lo que ha creado para facilitar un montón de trabajo a lo largo del tiempo, gracias a las librerías creadas (y en proceso de creación).
#
# Una *librería* o *paquete* es código organizado en un conjunto de funciones y clases implementadas por otras personas que nos facilitan realizar tareas, principalmente porque no debemos volver a programar este código.
#
#
# ## ¿Cómo Usamos una Librería?
#
# Para utilizar cualquier librería primero debemos *importarla*. Para ello, se usa la *palabra clave* **`import`**, pero hay muchas formas de emplearla. Sabiendo esto, una posibilidad es utilizar la siguiente sintaxis:
#
# > **`import`** (nombre de la libreria) **`as`** (nombre abreviado)
#
# De esta forma, estamos habilitando el uso de todo lo que contiene el paquete importado. El comando **`as`** nos permite indicar el nombre que le damos a la librería dentro de nuestro código.

# %%
import math as m

print('El seno de 0 es ', m.sin(0), 'y el coseno', m.cos(0))
# Out:
# El seno de 0 es  0.0 y el coseno 1.0

# %% [markdown]
# Por otro lado, las librerías muchas veces están separadas en distintos **módulos**. Podemos pensar entonces que una librería es un estante de libros, donde en cada libro se encuentran las funciones de un tema en común. Incluso un "libro" podría estar subdividido en "capítulos". Es decir, los distintos módulos de una librería podrían llegar a estar subdivididos en submódulos, y cada submódulo podría estar nuevamente subdividido, etc.
#
# En el caso de que no querramos importar la librería completa, podemos importar sólo un módulo, de esta forma:
#
# > **`from`** (nombre de la libreria) **`import`** (nombre de un módulo) **`as`** (nombre abreviado)
#
# Análogamente a la importación anterior, se puede usar un punto para acceder a un módulo, como se muestra a continuación:
#
# > **`import`** (nombre de la libreria)**.**(nombre de un módulo) **`as`** (nombre abreviado)
#
# Una vez importada una librería, podremos utilizar las funciones definidas en ella. Para poder hacer uso y ejecutar una función que se encuentra en una librería, necesitamos especificarlo usando un punto entre el nombre de la librería (o su nombre abreviado) y la función. La sintaxis es la siguiente:
#
# > (nombre de la libreria)**.**función*(argumentos)*
#
# En el caso de importar una librería que se encuentre dividida en módulos, debemos especificar el módulo correspondiente a la función nuevamente con un punto:
#
# > (nombre de la libreria)**.**(nombre del módulo)**.**función*(argumentos)*

# %%
from math import sin,cos #Importamos directamente las funciones que usaremos (separadas por comas)

print('El seno de 0 es ', sin(0), 'y el coseno', cos(0))
# Out:
# El seno de 0 es  0.0 y el coseno 1.0

# %%
dir(m)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %% [markdown]
# **Aclaraciones:**
# - **No es obligatorio especificar un nombre abreviado con `as`**, puede utilizarse una librería con su nombre original, omitiendo este comando. Sin embargo, utilizar abreviaturas puede simplificar la legibilidad del código.
# - Así como pueden importarse módulos de una librería, **también pueden importarse funciones sueltas**, según lo que necesiten. **Pero cuidado!** Los nombres de funciones deben ser únicos. Si importan una función directamente, entonces no podrán definir su propia función con el mismo nombre.
# - Es una **buena práctica** que todas las librerías se importen al principio del programa, o sea que las instrucciones de **`import`** se encuentren arriba de todo. Y es aún mejor práctica que los imports estén hechos en orden alfabético (aunque al principio sea mucho pedir).

# %%
import math #Importamos la libreria math

print('El seno de 0 es ', math.sin(0), 'y el coseno', math.cos(0))
# Out:
# El seno de 0 es  0.0 y el coseno 1.0

# %% [markdown]
# A continuación veremos diversos ejemplos de librerías, no para que las aprendan de memoria, sino para que conozcan el potencial de estas herramientas y puedan aprender a utilizar otras librerías nuevas en el futuro, que se adapten a sus necesidades y problemáticas particulares.

# %% [markdown]
# Algunas librerías muy conocidas y utilizadas, especialmente en ciencia de datos, son:
#
# *   [numpy](https://numpy.org/) (Cálculo matricial)
# *   [pandas](https://pandas.pydata.org/) (Lectura y manipulación de datos)
# *   [matplotlib](https://matplotlib.org/) (Gráficos)
# *   [seaborn](https://seaborn.pydata.org/) (Gráficos)
# *   [scipy](https://www.scipy.org/) (Ciencia de datos)
# *   [statsmodels](https://www.statsmodels.org/) (Econometria)
# *   [scikit-learn](https://scikit-learn.org) (Machine Learning)

# %% [markdown]
# ## Ejemplos de Librerías
#
# A continuación se presentan un conjunto de ejemplos con diversas librerías. Cada una de ellas ofrece muchas más opciones y capacidades, pero la idea es que les ayude a tener un panorama del tipo de herramientas que existen, y que se animen a buscar nuevas librerías que solucionen sus problemas específicos.
#
# Cabe destacar que algunas de estas librerías ya vienen incluídas con la instalación de Python, mientras que otras deben ser instaladas de forma independiente. En [este link](https://docs.python.org/3/library/) pueden investigar acerca de todas las librerías estándar que trae Python. Si cierta librería no se encuentra instalada en el sistema entonces el comando **`import`** para esa librería no funcionará con su instalación base de Python.
#
# La próxima clase ahondaremos más en la gestión y creación de entornos, donde aprenderán cómo instalar librerías nuevas no incluidas en la instalación de base, tanto en el entorno de Colab como en un entorno local.
#
# **Notas:**
#
# - Todas las librerías o paquetes cuentan con su **documentación**, la cual nos permite explorar los módulos que contiene y las funciones disponibles dentro de cada uno de ellos.
# - **Recurrir a la documentación** es muy útil e importante a la hora de entender cómo usar las herramientas disponibles en una librería.

# %% [markdown]
# ### [math](https://docs.python.org/3/library/math.html#module-math)
#
# - *Compilado de funciones matemáticas básicas*

# %%
import math

x = 10.14
print('Ceil de x', math.ceil(x))
print('Floor de x', math.floor(x))
print('Trunc de x', math.trunc(x)) # round
# Out:
# Ceil de x 11
# Floor de x 10
# Trunc de x 10

# %% [markdown]
# ### [random](https://docs.python.org/3/library/random.html)
#
# * *Generación aleatoria de números*

# %%
import random

opciones = ['Manzanas', 'Bananas', 'Naranjas']
print(random.choice(opciones))
# Out:
# Naranjas

# %%
# La función shuffle modifica el elemento que recibe como argumento!
random.shuffle(opciones)
print(opciones)
# Out:
# ['Naranjas', 'Manzanas', 'Bananas']

# %%
opciones
# Out:
# ['Naranjas', 'Manzanas', 'Bananas']

# %%
print(random.sample(opciones, k=1))
# Out:
# ['Manzanas']

# %%
lista = [1,2,3,4,5,6]

print(random.sample(lista, k=1))
# Out:
# [5]

# %%
# Entero aleatorio entre dos números (inclusive ambos)
print(random.randint( 10, 20 ))

# Decimal aleatorio entre [0.0, 1.0)
print(random.random())

# random.gauss(mu, sigma)
print(random.gauss(0, 1))
# Out:
# 11
# 0.1678663546605471
# 0.7888897311332722

# %% [markdown]
# ### [time](https://docs.python.org/3/library/time.html)
#
# * *Funciones relacionadas al manejo del tiempo*

# %%
import time

print(1)
time.sleep(5)
print(2)
time.sleep(1)
print(3)
time.sleep(1)
print(4)
time.sleep(1)
print(5)
time.sleep(1)
print('Adiós!')
# Out:
# 1
# 2
# 3
# 4
# 5
# Adiós!

# %%
time.time() # cantidad de segundos desde 1 enero 1970
# Out:
# 1749761902.2201533

# %%
start = time.time()
print("Hola")
end = time.time()

print("Imprimir esto nos tomó", end - start, "segundos")
# Out:
# Hola
# Imprimir esto nos tomó 0.029392480850219727 segundos

# %%
start = time.time()
time.sleep(5)
end = time.time()

print("Imprimir esto nos tomó", end - start, "segundos")
# Out:
# Imprimir esto nos tomó 5.001447916030884 segundos

# %%
#import numpy
#numpy.array([1,2])

# %%
# %%time
# funciona en archivos .ipynb
# Podemos imprimir el tiempo que toma correr una celda con %%time
print("Hola")
# Out:
# Hola
# CPU times: user 0 ns, sys: 403 µs, total: 403 µs
# Wall time: 922 µs

# %% [markdown]
# ### [datetime](https://docs.python.org/3/library/datetime.html)
#
# * *Manipulación de fechas y horarios*

# %%
from datetime import datetime, timedelta

now = datetime.now()
print(now.time())
# Out:
# 20:58:27.384491

# %%
print((now.year, now.month, now.day))
# Out:
# (2025, 6, 12)

# %%
print(f"La fecha es {now}")
# Out:
# La fecha es 2025-06-12 20:58:27.384491

# %%
# Algo de f-strings
print(f"Hoy es {now:%B %d, %Y}") # utilizo el objeto now como referencia, con el formato %B %d, %Y
# Out:
# Hoy es June 12, 2025

# %%
new_time = datetime(2010, 2, 6, 10, 8, 20, 0) # (año, mes, dia, [hora, minuto, segundo, milisegundo])

print(new_time)
new_time = new_time + timedelta(days=5, hours=1)
print(new_time)
# Out:
# 2010-02-06 10:08:20
# 2010-02-11 11:08:20

# %% [markdown]
# ### [NumPy](https://numpy.org/)
# * *Cálculo algebraico*
#
# NumPy permite crear vectores y matrices multidimensionales, junto con una gran colección de funciones matemáticas de alto nivel para operar con ellos de forma muy eficiente.

# %%
import numpy as np

A = np.array([
    [1,2,3],
    [4,5,6],
])

B = np.array([[1,2], [4,5], [7,8]])

C = np.dot(A, B)

print('A =')
print(A)
print()
print('B =')
print(B)
print()
print('A*B =')
print(C)
# Out:
# A =
# [[1 2 3]
#  [4 5 6]]
#
# B =
# [[1 2]
#  [4 5]
#  [7 8]]
#
# A*B =
# [[30 36]
#  [66 81]]

# %%
type(A)
# Out:
# numpy.ndarray

# %%
# Veamos la diferencia entre listas o arrays
# Suma o producto de listas concatena
a = [2, 4]
print(a + a)
print(a * 3)

# Suma o producto de numpy arrays aplica la operación elemento a elemento
a = np.array(a)
print(a + a)
print(a * 3)
# Out:
# [2, 4, 2, 4]
# [2, 4, 2, 4, 2, 4]
# [4 8]
# [ 6 12]

# %% [markdown]
# # Cálculos Matriciales y Entre *Arrays* con Numpy
#
# En la siguiente sección, profundizaremos sobre la utilización de la librería Numpy, que se usa principalmente para operar con matrices o *arrays*.
#
# El elemento básico sobre el que se opera en Numpy se lo denomina *array*. Un ***array*** en Numpy es lo que conocemos como vector o matriz y sus valores son listas con una restricción especial: que sus valores sean todos del mismo tipo.

# %%
import numpy as np

# Tenemos 3 matrices y varias operaciones para realizar entre ellas.

A = np.array([
    [3, 0.],
    [-1, 2],
    [1, 1],
])

B = np.array([
    [4, -1.],
    [0, 2],
])

C = np.array([
    [1., 1, -1],
    [2, -1, 1],
])

print(A @ B) #producto matricial
print(B @ C)
print(A @ A.T) #producto matricial y la segunda matriz es traspuesta
print(A.T @ A)
print(A + C.T)
print(2 * A)
# Out:
# [[12. -3.]
#  [-4.  5.]
#  [ 4.  1.]]
# [[ 2.  5. -5.]
#  [ 4. -2.  2.]]
# [[ 9. -3.  3.]
#  [-3.  5.  1.]
#  [ 3.  1.  2.]]
# [[11. -1.]
#  [-1.  5.]]
# [[4. 2.]
#  [0. 1.]
#  [0. 2.]]
# [[ 6.  0.]
#  [-2.  4.]
#  [ 2.  2.]]

# %%
# Sistemas lineales
# x + y = 2
# 5x + 6y = 9

sistema = np.array([
    [1., 1],
    [5, 6],
])
vector = np.array([2, 9])
print(np.linalg.solve(sistema, vector))

# x + 3y + z = 0
# 2x + 2y + z = -1
# 2x + 3y + z = 2

sistema = np.array([
    [1., 3, 1],
    [2, 2, 1],
    [2, 3, 1],
])
vector = np.array([0, -1, 2])
print(np.linalg.solve(sistema, vector))
# Out:
# [ 3. -1.]
# [  2.   3. -11.]

# %% [markdown]
# ### [Matplotlib](https://matplotlib.org)
# * *Visualización de datos*

# %%
# Ejemplo obtenido de la documentación de matplotlib para darse una idea del
# uso de esta herramienta
# No es necesario entender cómo funciona

import numpy as np
import matplotlib.pyplot as plt #apodos estándar de las librerías numpy y matplotlib

# example data
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(437)

num_bins = 50

plt.plot(figsize=(20, 10))

# the histogram of the data
n, bins, patches = plt.hist(x, num_bins, density=True)

# add a 'best fit' line
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *
     np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins, y, 'r--')
plt.title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
plt.show()

# %% [markdown]
# # Importación y Exportación de Datos Utilizando Pandas (Datos Estructurados)
#
# Lo más común es encontrarse con archivos con formato ***.csv*** o ***.xlsx***, que contienen datos con cierta estructura.
#
# Para importar datos de este tipo, existe una librería que nos facilitará mucho la tarea, ya que está pensada y diseñada para el manejo de datos. [**Pandas**](https://pandas.pydata.org/docs/reference/index.html#api) es un paquete de manipulación de datos de alto nivel y que está construída sobre **Numpy** (podemos pensarla como una capa superior).
#
# En esta sección aprenderemos cómo importar datos a nuestro programa y también cómo podemos guardarlos nuevamente.

# %% [markdown]
# ## Importación de Datos
#
# La función de Pandas que nos permite leer un csv es **`read_csv()`**, donde como argumento recibe la ubicación del archivo que queremos leer. Veamos un ejemplo, en el que guardamos los datos leidos en una variable `df`, utilizando los datos de muestra que tenemos en Colab:

# %%
import pandas as pd

try:
  df = pd.read_excel('/content/drive/Shareddrives/Curso Python para Finanzas/Clase 2/cotizacion_acciones.xlsx')
  df
except:
  url="https://docs.google.com/spreadsheets/d/1-8T1ksYcPjHglkQyWj9BOejQwULRQyXB/edit?usp=sharing&ouid=104233125873246966527&rtpof=true&sd=true"
  path = 'https://drive.google.com/uc?export=download&id=' + url.split('/')[-2]

  df = pd.read_excel(path)
  df

# %% [markdown]
# Veamos qué se almacenó en la variable **`df`**, explorando primero su tipo y luego el contenido.

# %%
print('Tipo de df:', type(df), '\n')
print('Contenido de df:\n', df)
# Out:
# Tipo de df: <class 'pandas.core.frame.DataFrame'>
#
# Contenido de df:
#             Date      BBAR        BMA      CEPU       GGAL       LOMA  \
# 0    2019-06-10  7.393730  43.780521  6.700587  22.641754   8.953540
# 1    2019-06-11  8.192004  46.753693  7.261762  24.410273   9.680427
# 2    2019-06-12  8.788774  51.860291  7.722426  27.455605  10.296143
# 3    2019-06-13  8.548517  51.769501  7.521409  27.003559   9.988284
# 4    2019-06-14  8.571768  49.749561  7.387396  26.091551   9.731736
# ...         ...       ...        ...       ...        ...        ...
# 1254 2024-06-03  9.565948  59.528622  9.380000  32.874107   7.320000
# 1255 2024-06-04  8.812993  55.704254  8.990000  30.694815   6.990000
# 1256 2024-06-05  8.787324  54.764137  8.850000  30.704044   7.120000
# 1257 2024-06-06  8.256833  52.409279  8.690000  29.097279   7.050000
# 1258 2024-06-07  8.368065  52.089821  8.730000  29.245029   6.990000
#
#             PAM      SUPV        TGS         TS        YPF
# 0     26.959999  5.948011  13.380000  21.395897  16.007223
# 1     29.900000  7.015843  14.340000  21.895880  16.622503
# 2     33.660000  7.399889  15.000000  20.801081  17.088926
# 3     32.389999  7.193816  14.750000  21.421757  17.009535
# 4     31.820000  6.969008  14.790000  20.706263  16.870602
# ...         ...       ...        ...        ...        ...
# 1254  47.450001  6.960000  18.850000  31.815166  22.100000
# 1255  44.189999  6.400000  17.799999  31.785601  20.280001
# 1256  44.369999  6.400000  17.799999  31.716608  20.809999
# 1257  43.720001  6.160000  17.260000  31.785601  20.100000
# 1258  43.450001  6.200000  16.950001  31.539200  20.020000
#
# [1259 rows x 11 columns]

# %% [markdown]
# Exploremos un poco algunas propiedades como:
# - Cantidad de filas y columnas: para ello consultaremos el *atributo* **`shape`**.
# - Contenido de las primeras 10 filas: para ello utilizaremos el método **`head()`**.

# %%
print('Cantidad de (filas, columnas) de df:', df.shape, '\n')
# Out:
# Cantidad de (filas, columnas) de df: (1259, 11)

# %%
df.head()
# Out:
#         Date      BBAR        BMA      CEPU       GGAL       LOMA        PAM  \
# 0 2019-06-10  7.393730  43.780521  6.700587  22.641754   8.953540  26.959999
# 1 2019-06-11  8.192004  46.753693  7.261762  24.410273   9.680427  29.900000
# 2 2019-06-12  8.788774  51.860291  7.722426  27.455605  10.296143  33.660000
# 3 2019-06-13  8.548517  51.769501  7.521409  27.003559   9.988284  32.389999
# 4 2019-06-14  8.571768  49.749561  7.387396  26.091551   9.731736  31.820000
#
#        SUPV    TGS         TS        YPF
# 0  5.948011  13.38  21.395897  16.007223
# 1  7.015843  14.34  21.895880  16.622503
# 2  7.399889  15.00  20.801081  17.088926
# 3  7.193816  14.75  21.421757  17.009535
# 4  6.969008  14.79  20.706263  16.870602

# %%
df.tail(10)
# Out:
#            Date      BBAR        BMA   CEPU       GGAL  LOMA        PAM  SUPV  \
# 1249 2024-05-24  8.419403  53.212486   9.48  29.983776  6.93  45.720001  6.48
# 1250 2024-05-28  8.522079  54.134350   9.91  30.537832  7.10  47.660000  6.55
# 1251 2024-05-29  8.753098  56.543972  10.00  31.553600  7.23  48.529999  6.77
# 1252 2024-05-30  9.711406  60.286194  10.40  34.056103  7.52  50.209999  7.49
# 1253 2024-05-31  9.660068  60.505249   9.94  33.104965  7.46  49.349998  7.24
# 1254 2024-06-03  9.565948  59.528622   9.38  32.874107  7.32  47.450001  6.96
# 1255 2024-06-04  8.812993  55.704254   8.99  30.694815  6.99  44.189999  6.40
# 1256 2024-06-05  8.787324  54.764137   8.85  30.704044  7.12  44.369999  6.40
# 1257 2024-06-06  8.256833  52.409279   8.69  29.097279  7.05  43.720001  6.16
# 1258 2024-06-07  8.368065  52.089821   8.73  29.245029  6.99  43.450001  6.20
#
#             TGS         TS        YPF
# 1249  17.980000  33.116158  21.010000
# 1250  19.100000  33.806080  22.250000
# 1251  18.830000  32.436096  22.459999
# 1252  20.480000  32.229122  23.910000
# 1253  19.639999  32.495232  23.209999
# 1254  18.850000  31.815166  22.100000
# 1255  17.799999  31.785601  20.280001
# 1256  17.799999  31.716608  20.809999
# 1257  17.260000  31.785601  20.100000
# 1258  16.950001  31.539200  20.020000

# %%
df.sample(10)
# Out:
#            Date      BBAR        BMA       CEPU       GGAL      LOMA  \
# 773  2022-07-05  1.836807   8.884702   2.598199   5.759375  4.310013
# 1019 2023-06-27  4.867560  21.530310   6.062295  14.929904  6.647739
# 120  2019-11-27  3.100097  20.191843   3.358669  10.928313  5.815097
# 776  2022-07-08  1.844557   9.050995   2.693150   5.624653  4.019258
# 442  2021-03-11  2.224319  10.750324   1.933544   6.304731  5.148071
# 1234 2024-05-03  8.975563  54.964943  10.880000  31.692118  7.420000
# 176  2020-02-20  3.534110  25.646441   3.072953  11.348634  5.541445
# 775  2022-07-07  1.782556   8.971807   2.736310   5.633073  4.378426
# 110  2019-11-13  2.487827  18.353474   2.713738   9.199453  5.105313
# 1112 2023-11-07  3.615716  17.642590   5.352217  11.145801  6.190000
#
#             PAM      SUPV        TGS         TS        YPF
# 773   19.750000  1.356291   4.900000  21.823315   3.130000
# 1019  41.799999  2.937004  13.150000  27.072159  14.990000
# 120   13.890000  2.819451   6.120000  18.817762   9.680000
# 776   20.959999  1.336776   5.040000  23.779697   3.170000
# 442   13.970000  1.761002   4.690000  20.750671   4.400000
# 1234  48.740002  6.703395  19.200001  32.554001  23.379999
# 176   13.210000  2.885020   6.420000  18.372839   9.700000
# 775   20.850000  1.287989   5.140000  22.870392   3.120000
# 110   13.170000  2.313636   6.240000  18.654596   8.960000
# 1112  36.959999  1.980770  10.340000  32.726467  10.140000

# %% [markdown]
# ## Exportación de Datos
#
# Supongamos ahora que necesitamos guardar en un nuevo archivo csv las 100 primeras líneas del archivo original. **Pandas** también tiene prevista esta tarea. Para esto, usaremos el método de Pandas **`to_csv()`**, que se aplica sobre un ***DataFrame*** y recibe como argumento el *path* donde se guardarán los datos.
#
# Veamos cómo aplicarlo:

# %%
df.to_excel("/content/Base de Datos.xlsx")

# %% [markdown]
# ## Exploración de bases de datos
#
# Estas funciones de pandas son fundamentales para conocer la estructura de un DataFrame. **df.columns** muestra una lista con los nombres de las columnas, lo cual es útil para verificar la estructura o acceder a columnas específicas. **df.info(**) brinda un resumen general que incluye la cantidad de filas, el tipo de dato de cada columna y cuántos valores no nulos hay por columna, lo que permite identificar rápidamente problemas como datos faltantes. Por su parte, **df.describe()** calcula estadísticas descriptivas básicas (como media, desviación estándar, mínimo, máximo y percentiles) para las columnas numéricas, ayudando a entender la distribución y el rango de los datos.

# %%
df.columns
# Out:
# Index(['Date', 'BBAR', 'BMA', 'CEPU', 'GGAL', 'LOMA', 'PAM', 'SUPV', 'TGS',
#        'TS', 'YPF'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1259 non-null   datetime64[ns]
#  1   BBAR    1259 non-null   float64
#  2   BMA     1259 non-null   float64
#  3   CEPU    1259 non-null   float64
#  4   GGAL    1259 non-null   float64
#  5   LOMA    1259 non-null   float64
#  6   PAM     1259 non-null   float64
#  7   SUPV    1259 non-null   float64
#  8   TGS     1259 non-null   float64
#  9   TS      1259 non-null   float64
#  10  YPF     1259 non-null   float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 108.3 KB

# %%
df.describe()
# Out:
#                                 Date         BBAR          BMA         CEPU  \
# count                           1259  1259.000000  1259.000000  1259.000000
# mean   2021-12-06 17:00:14.297061120     3.462623    18.278728     4.096595
# min              2019-06-10 00:00:00     1.666302     7.918630     1.657323
# 25%              2020-09-06 00:00:00     2.379324    11.272330     2.321979
# 50%              2021-12-06 00:00:00     2.921841    14.017083     3.193800
# 75%              2023-03-08 12:00:00     3.754405    20.207996     5.449852
# max              2024-06-07 00:00:00    10.010875    61.062016    11.060000
# std                              NaN     1.732558    11.241744     2.294926
#
#               GGAL         LOMA          PAM         SUPV          TGS  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean     10.789922     5.607208    24.210667     2.617842     8.228133
# min       4.702823     2.745068     9.020000     1.219686     3.840000
# 25%       6.808924     4.900074    14.230000     1.818116     5.100000
# 50%       8.428390     5.567101    20.049999     2.156376     6.450000
# 75%      11.665692     6.224332    33.904999     2.808084    11.260000
# max      34.425468    11.014478    50.560001     8.242913    20.480000
# std       6.175230     1.317570    11.945224     1.364621     3.884693
#
#                 TS          YPF
# count  1259.000000  1259.000000
# mean     22.595091     8.655754
# min       7.982501     2.570000
# 25%      18.010391     4.380000
# 50%      21.533819     6.600000
# 75%      29.785473    11.560000
# max      38.795124    24.459999
# std       7.553430     5.166117

# %% [markdown]
# ## Exploración de bases de datos
#
# Estas funciones permiten acceder y filtrar datos dentro de un DataFrame en pandas. Usando **df['col']** o **df.col** se accede a una única columna, mientras que **df[['col1', 'col2']]** permite seleccionar varias columnas a la vez. Para acceder a elementos específicos, **df.loc[etiqueta_fila, columna]** utiliza las etiquetas de fila y columna, mientras que **df.iloc[fila, columna]** lo hace mediante índices numéricos. Finalmente, **df[df['col'] > valor]** permite aplicar filtros condicionales, devolviendo solo las filas que cumplen con la condición especificada. Estas herramientas son esenciales para manipular y explorar datos de forma flexible y precisa.

# %%
df.head()
# Out:
#         Date      BBAR        BMA      CEPU       GGAL       LOMA        PAM  \
# 0 2019-06-10  7.393730  43.780521  6.700587  22.641754   8.953540  26.959999
# 1 2019-06-11  8.192004  46.753693  7.261762  24.410273   9.680427  29.900000
# 2 2019-06-12  8.788774  51.860291  7.722426  27.455605  10.296143  33.660000
# 3 2019-06-13  8.548517  51.769501  7.521409  27.003559   9.988284  32.389999
# 4 2019-06-14  8.571768  49.749561  7.387396  26.091551   9.731736  31.820000
#
#        SUPV    TGS         TS        YPF
# 0  5.948011  13.38  21.395897  16.007223
# 1  7.015843  14.34  21.895880  16.622503
# 2  7.399889  15.00  20.801081  17.088926
# 3  7.193816  14.75  21.421757  17.009535
# 4  6.969008  14.79  20.706263  16.870602

# %% [markdown]
# ## Transformacion de Datos
#
# Las funciones de transformación de datos en pandas permiten modificar la estructura o el contenido de un DataFrame de forma eficiente. Con df.copy() se crea una copia independiente del DataFrame original, útil para evitar modificar los datos por error. **df.drop(columns=['col1'])** elimina columnas específicas, y **df.rename(columns={'viejo':'nuevo'})** permite cambiar sus nombres. Para asegurar la coherencia en los tipos de datos, **df.astype({'col': tipo})** convierte columnas a un tipo determinado. En cuanto al tratamiento de valores faltantes, **df.fillna(valor)** permite reemplazarlos con un valor definido, mientras que **df.dropna()** elimina directamente las filas que contienen valores nulos. Estas funciones son clave para preparar los datos antes de analizarlos o modelarlos.

# %% [markdown]
# ## Gráfico de Lineas
#
#
# Para la visualización, se empleó **plt.plot()** que permite trazar líneas representando la evolución del precio de cada acción a lo largo del tiempo. La función **plt.figure(figsize=(10, 5))** definió el tamaño del gráfico, mientras que **plt.title()**, **plt.xlabel()** y **plt.ylabel()** agregaron el título y etiquetas a los ejes, mejorando la legibilidad. Se activó una cuadrícula de fondo con **plt.grid(True)** para facilitar la lectura visual de los valores, y con **plt.legend()** se incluyó una leyenda que identifica cada serie graficada. Finalmente, **plt.show()** permitió visualizar el gráfico generado. Estas herramientas combinadas resultan muy útiles para explorar y comparar visualmente el comportamiento de activos financieros a lo largo del tiempo.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['YPF'], label='YPF')
plt.title('Cotización histórica de YPF')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['GGAL'], label='GGAL')
plt.plot(df['BMA'], label='BMA')
plt.plot(df['TS'], label='TS')
plt.title('Comparativa de cotizaciones: GGAL, BMA y TS')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.grid(True)
plt.legend()
plt.show()
